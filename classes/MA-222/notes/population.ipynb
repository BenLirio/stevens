# %%
using Plots

# %%
data = [
    (1,.14),
    (2, .175),
    (3, .22),
    (4, .26),
    (5, .155),
    (6, .025),
    (7, .015),
    (8, .005),
    (9, .004),
    (10, .001),
]
data_reverse = []
for element in data
    push!(data_reverse, [element[1], element[2])
end
println(data)
# Out:
# syntax: missing separator in array expression
#
# Stacktrace:
#  [1] top-level scope at In[43]:15

# %%
plot(data, title="Household population")
